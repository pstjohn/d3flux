# %% [markdown]
# ## Simple d3.js based flux visualizations

# %% [markdown]
# Here we build a simple metabolic modeling using `cobra`

# %%
from cobra.core import Metabolite, Reaction, Model

model = Model('simple_model')

A = Metabolite('A')
B = Metabolite('B')
C = Metabolite('C')
D = Metabolite('D')
E = Metabolite('E')
P = Metabolite('P')

R1 = Reaction('R1')
R2 = Reaction('R2')
R3 = Reaction('R3')
R4 = Reaction('R4')
R5 = Reaction('R5')
R6 = Reaction('R6')
R7 = Reaction('R7')
R8 = Reaction('R8')
R9 = Reaction('R9')
R10 = Reaction('R10')

model.add_metabolites([A, B, C, D, E, P])
model.add_reactions([R1, R2, R3, R4, R5, R6, R7, R8, R9, R10])

model.reactions.R1.build_reaction_from_string('--> A')
model.reactions.R2.build_reaction_from_string('<--> B')
model.reactions.R3.build_reaction_from_string('P -->')
model.reactions.R4.build_reaction_from_string('E -->')
model.reactions.R5.build_reaction_from_string('A --> B')
model.reactions.R6.build_reaction_from_string('A --> C')
model.reactions.R7.build_reaction_from_string('A --> D')
model.reactions.R8.build_reaction_from_string('B <--> C')
model.reactions.R9.build_reaction_from_string('B --> P')
model.reactions.R10.build_reaction_from_string('C + D --> E + P')

# %% [markdown]
# ### Simple visualizations without starting positions
#
# Without specifying locations for each metabolite and/or reaction, the map will use `d3.js` to display the network as  a force-directed layout.

# %%
from d3flux import flux_map
flux_map(model, display_name_format=lambda x: str(x.id), figsize=(300,250))
# Out:
# <div id="d3flux001">
#   <style scoped>
#   #d3flux001 svg {
#     height: 250px;
#     width: 300px;
# }
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .node.rxn {
#   fill: #FFA319;
# }
#
# .node.rxn.hidden {
#   fill: none;
#   stroke: none;
#   stroke-width: 0;
# }
#
# .link {
#   fill: none;
#   stroke-linecap = round;
# }
#
# text.nodelabel {
#   fill: #555;
#   font-family: Arial;
#   font-size: 12;
#   pointer-events: none;
# }
#
#   </style>
#
# </div>
# <div id="d3flux001_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux001model = {"genes": [], "pathways": [], "id": "simple_model", "version": 1, "metabolites": [{"id": "A", "formula": "", "notes": {"map_info": {"display_name": "A"}}, "compartment": "", "name": ""}, {"id": "B", "formula": "", "notes": {"map_info": {"display_name": "B"}}, "compartment": "", "name": ""}, {"id": "C", "formula": "", "notes": {"map_info": {"display_name": "C"}}, "compartment": "", "name": ""}, {"id": "D", "formula": "", "notes": {"map_info": {"display_name": "D"}}, "compartment": "", "name": ""}, {"id": "E", "formula": "", "notes": {"map_info": {"display_name": "E"}}, "compartment": "", "name": ""}, {"id": "P", "formula": "", "notes": {"map_info": {"display_name": "P"}}, "compartment": "", "name": ""}], "reactions": [{"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R1", "metabolites": {"A": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "hidden": true}}, "name": "", "id": "R2", "metabolites": {"B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R3", "metabolites": {"P": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R4", "metabolites": {"E": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R5", "metabolites": {"A": -1, "B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R6", "metabolites": {"A": -1, "C": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R7", "metabolites": {"D": 1, "A": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true}}, "name": "", "id": "R8", "metabolites": {"C": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R9", "metabolites": {"B": -1, "P": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R10", "metabolites": {"D": -1, "C": -1, "P": 1, "E": 1}, "gene_reaction_rule": "", "upper_bound": 1000}], "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip"
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux001").append("svg")
#         .attr("width", width)
#         .attr("height", height);
#     } else {
#       var svg = d3.select("#d3flux001").select("svg");
#     }
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux001_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux001_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);
#         }
#       }
#       return math.mean(angles).toPolar().phi;
#     }
#
#     function average_dist(rxn, rstoich, nodes) {
#       // Calculate the average distance to the reaction nodes, which is u

# %% [markdown]
# Nodes and reactions can be dragged into position, where they will 'stick'. Double-clicking a stuck node releases it.
# The coordinates (and other visualization properties) of the nodes are saved in the `'map_info'` field of the `metabolite.notes` dictionary.
#
# The positions can be passed manually:

# %%
A.notes['map_info']['x'] = 150.
A.notes['map_info']['y'] = 50.

B.notes['map_info']['x'] = 80.
B.notes['map_info']['y'] = 130.

C.notes['map_info']['x'] = 150.
C.notes['map_info']['y'] = 130.

D.notes['map_info']['x'] = 220.
D.notes['map_info']['y'] = 130.

P.notes['map_info']['x'] = 150.
P.notes['map_info']['y'] = 200.

E.notes['map_info']['x'] = 220.
E.notes['map_info']['y'] = 200.

# %%
flux_map(model, display_name_format=lambda x: str(x.id), figsize=(300,250))
# Out:
# <div id="d3flux002">
#   <style scoped>
#   #d3flux002 svg {
#     height: 250px;
#     width: 300px;
# }
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .node.rxn {
#   fill: #FFA319;
# }
#
# .node.rxn.hidden {
#   fill: none;
#   stroke: none;
#   stroke-width: 0;
# }
#
# .link {
#   fill: none;
#   stroke-linecap = round;
# }
#
# text.nodelabel {
#   fill: #555;
#   font-family: Arial;
#   font-size: 12;
#   pointer-events: none;
# }
#
#   </style>
#
# </div>
# <div id="d3flux002_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux002model = {"genes": [], "pathways": [], "id": "simple_model", "version": 1, "metabolites": [{"id": "A", "formula": "", "notes": {"map_info": {"x": 150.0, "y": 50.0, "display_name": "A"}}, "compartment": "", "name": ""}, {"id": "B", "formula": "", "notes": {"map_info": {"x": 80.0, "y": 130.0, "display_name": "B"}}, "compartment": "", "name": ""}, {"id": "C", "formula": "", "notes": {"map_info": {"x": 150.0, "y": 130.0, "display_name": "C"}}, "compartment": "", "name": ""}, {"id": "D", "formula": "", "notes": {"map_info": {"x": 220.0, "y": 130.0, "display_name": "D"}}, "compartment": "", "name": ""}, {"id": "E", "formula": "", "notes": {"map_info": {"x": 220.0, "y": 200.0, "display_name": "E"}}, "compartment": "", "name": ""}, {"id": "P", "formula": "", "notes": {"map_info": {"x": 150.0, "y": 200.0, "display_name": "P"}}, "compartment": "", "name": ""}], "reactions": [{"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R1", "metabolites": {"A": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "hidden": true}}, "name": "", "id": "R2", "metabolites": {"B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R3", "metabolites": {"P": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R4", "metabolites": {"E": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R5", "metabolites": {"A": -1, "B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R6", "metabolites": {"A": -1, "C": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R7", "metabolites": {"D": 1, "A": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true}}, "name": "", "id": "R8", "metabolites": {"C": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R9", "metabolites": {"B": -1, "P": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R10", "metabolites": {"D": -1, "C": -1, "P": 1, "E": 1}, "gene_reaction_rule": "", "upper_bound": 1000}], "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip"
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux002").append("svg")
#         .attr("width", width)
#         .attr("height", height);
#     } else {
#       var svg = d3.select("#d3flux002").select("svg");
#     }
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux002_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux002_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);
#         }
#       }
#       return math.mean(angles).to

# %% [markdown]
# Saving the model using the `Save JSON` button will include the updated map info if nodes are dragged to their desired locations

# %%
from cobra.io import load_json_model
new_model = load_json_model('simple_model.json')
flux_map(new_model, figsize=(300,250))
# Out:
# <div id="d3flux003">
#   <style scoped>
#   #d3flux003 svg {
#     height: 250px;
#     width: 300px;
# }
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .node.rxn {
#   fill: #FFA319;
# }
#
# .node.rxn.hidden {
#   fill: none;
#   stroke: none;
#   stroke-width: 0;
# }
#
# .link {
#   fill: none;
#   stroke-linecap = round;
# }
#
# text.nodelabel {
#   fill: #555;
#   font-family: Arial;
#   font-size: 12;
#   pointer-events: none;
# }
#
#   </style>
#
# </div>
# <div id="d3flux003_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux003model = {"genes": [], "pathways": [], "id": "simple_model", "version": 1, "metabolites": [{"id": "A", "formula": "", "notes": {"map_info": {"x": 150, "y": 50, "display_name": "A"}}, "compartment": "", "name": ""}, {"id": "B", "formula": "", "notes": {"map_info": {"x": 80, "y": 130, "display_name": "B"}}, "compartment": "", "name": ""}, {"id": "C", "formula": "", "notes": {"map_info": {"x": 150, "y": 130, "display_name": "C"}}, "compartment": "", "name": ""}, {"id": "D", "formula": "", "notes": {"map_info": {"x": 220, "y": 130, "display_name": "D"}}, "compartment": "", "name": ""}, {"id": "E", "formula": "", "notes": {"map_info": {"x": 220, "y": 200, "display_name": "E"}}, "compartment": "", "name": ""}, {"id": "P", "formula": "", "notes": {"map_info": {"x": 150, "y": 200, "display_name": "P"}}, "compartment": "", "name": ""}], "reactions": [{"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R1", "metabolites": {"A": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "hidden": true}}, "name": "", "id": "R2", "metabolites": {"B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R3", "metabolites": {"P": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true}}, "name": "", "id": "R4", "metabolites": {"E": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R5", "metabolites": {"A": -1, "B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R6", "metabolites": {"A": -1, "C": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R7", "metabolites": {"D": 1, "A": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true}}, "name": "", "id": "R8", "metabolites": {"C": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R9", "metabolites": {"P": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false}}, "name": "", "id": "R10", "metabolites": {"D": -1, "C": -1, "P": 1, "E": 1}, "gene_reaction_rule": "", "upper_bound": 1000}], "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip"
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux003").append("svg")
#         .attr("width", width)
#         .attr("height", height);
#     } else {
#       var svg = d3.select("#d3flux003").select("svg");
#     }
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux003_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux003_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);
#         }
#       }
#       return math.mean(angles).toPolar().phi;
#     }

# %% [markdown]
# ## Plotting metabolic flux results
#
# A model with a valid `solution` dictionary will have the reaction arrows scaled by their corresponding flux.

# %%
model.objective = model.reactions.R4
model.optimize()

flux_map(model, figsize=(300,250))
# Out:
# <div id="d3flux004">
#   <style scoped>
#   #d3flux004 svg {
#     height: 250px;
#     width: 300px;
# }
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .node.rxn {
#   fill: #FFA319;
# }
#
# .node.rxn.hidden {
#   fill: none;
#   stroke: none;
#   stroke-width: 0;
# }
#
# .link {
#   fill: none;
#   stroke-linecap = round;
# }
#
# text.nodelabel {
#   fill: #555;
#   font-family: Arial;
#   font-size: 12;
#   pointer-events: none;
# }
#
#   </style>
#
# </div>
# <div id="d3flux004_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux004model = {"genes": [], "pathways": [], "id": "simple_model", "version": 1, "metabolites": [{"id": "A", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 150.0, "y": 50.0, "display_name": "A"}}, "compartment": "", "name": ""}, {"id": "B", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 80.0, "y": 130.0, "display_name": "B"}}, "compartment": "", "name": ""}, {"id": "C", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 150.0, "y": 130.0, "display_name": "C"}}, "compartment": "", "name": ""}, {"id": "D", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 220.0, "y": 130.0, "display_name": "D"}}, "compartment": "", "name": ""}, {"id": "E", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 220.0, "y": 200.0, "display_name": "E"}}, "compartment": "", "name": ""}, {"id": "P", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 150.0, "y": 200.0, "display_name": "P"}}, "compartment": "", "name": ""}], "reactions": [{"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}, "name": "", "id": "R1", "metabolites": {"A": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "hidden": true, "flux": 1000.0}}, "name": "", "id": "R2", "metabolites": {"B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}, "name": "", "id": "R3", "metabolites": {"P": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}, "name": "", "id": "R4", "metabolites": {"E": -1}, "objective_coefficient": 1, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 0.0}}, "name": "", "id": "R5", "metabolites": {"A": -1, "B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 0.0}}, "name": "", "id": "R6", "metabolites": {"A": -1, "C": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 1000.0}}, "name": "", "id": "R7", "metabolites": {"D": 1, "A": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "flux": 1000.0}}, "name": "", "id": "R8", "metabolites": {"C": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 0.0}}, "name": "", "id": "R9", "metabolites": {"B": -1, "P": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 1000.0}}, "name": "", "id": "R10", "metabolites": {"D": -1, "C": -1, "P": 1, "E": 1}, "gene_reaction_rule": "", "upper_bound": 1000}], "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip"
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux004").append("svg")
#         .attr("width", width)
#         .attr("height", height);
#     } else {
#       var svg = d3.select("#d3flux004").select("svg");
#     }
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux004_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux004_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.

# %% [markdown]
# ### Simulating flux knockouts
#
# The `flux_map` will also show reactions which have been knocked out

# %%
model.reactions.R8.knock_out()
model.optimize()
flux_map(model, figsize=(300,250))
# Out:
# <div id="d3flux006">
#   <style scoped>
#   #d3flux006 svg {
#     height: 250px;
#     width: 300px;
# }
#
# .node {
#   stroke: #fff;
#   stroke-width: 1.5px;
# }
#
# .node.rxn {
#   fill: #FFA319;
# }
#
# .node.rxn.hidden {
#   fill: none;
#   stroke: none;
#   stroke-width: 0;
# }
#
# .link {
#   fill: none;
#   stroke-linecap = round;
# }
#
# text.nodelabel {
#   fill: #555;
#   font-family: Arial;
#   font-size: 12;
#   pointer-events: none;
# }
#
#   </style>
#
# </div>
# <div id="d3flux006_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux006model = {"genes": [], "pathways": [], "id": "simple_model", "version": 1, "metabolites": [{"id": "A", "formula": "", "notes": {"map_info": {"flux": 1000.0, "x": 150.0, "y": 50.0, "display_name": "A"}}, "compartment": "", "name": ""}, {"id": "B", "formula": "", "notes": {"map_info": {"flux": 0.0, "x": 80.0, "y": 130.0, "display_name": "B"}}, "compartment": "", "name": ""}, {"id": "C", "formula": "", "notes": {"map_info": {"flux": 500.0, "x": 150.0, "y": 130.0, "display_name": "C"}}, "compartment": "", "name": ""}, {"id": "D", "formula": "", "notes": {"map_info": {"flux": 500.0, "x": 220.0, "y": 130.0, "display_name": "D"}}, "compartment": "", "name": ""}, {"id": "E", "formula": "", "notes": {"map_info": {"flux": 500.0, "x": 220.0, "y": 200.0, "display_name": "E"}}, "compartment": "", "name": ""}, {"id": "P", "formula": "", "notes": {"map_info": {"flux": 500.0, "x": 150.0, "y": 200.0, "display_name": "P"}}, "compartment": "", "name": ""}], "reactions": [{"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}, "name": "", "id": "R1", "metabolites": {"A": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": -1000, "notes": {"map_info": {"reversibility": true, "hidden": true, "flux": 0.0}}, "name": "", "id": "R2", "metabolites": {"B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 500.0}}, "name": "", "id": "R3", "metabolites": {"P": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 500.0}}, "name": "", "id": "R4", "metabolites": {"E": -1}, "objective_coefficient": 1, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 0.0}}, "name": "", "id": "R5", "metabolites": {"A": -1, "B": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 500.0}}, "name": "", "id": "R6", "metabolites": {"A": -1, "C": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 500.0}}, "name": "", "id": "R7", "metabolites": {"D": 1, "A": -1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "group": "ko"}}, "name": "", "id": "R8", "metabolites": {"C": 1, "B": -1}, "gene_reaction_rule": "", "upper_bound": 0}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 0.0}}, "name": "", "id": "R9", "metabolites": {"B": -1, "P": 1}, "gene_reaction_rule": "", "upper_bound": 1000}, {"lower_bound": 0, "notes": {"map_info": {"reversibility": false, "flux": 500.0}}, "name": "", "id": "R10", "metabolites": {"D": -1, "C": -1, "P": 1, "E": 1}, "gene_reaction_rule": "", "upper_bound": 1000}], "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "http://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip"
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux006").append("svg")
#         .attr("width", width)
#         .attr("height", height);
#     } else {
#       var svg = d3.select("#d3flux006").select("svg");
#     }
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux006_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux006_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
